# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: VISUALIZACION BASICA

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste en un único ejercicio de construcción de gráficas. Descarga este notebook en tu ordenador y trabaja en local. Ten en cuenta que tendrás que descar los directorios de imágenes y datos adicionales, si los hubiera.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### Ejercicio 0

# %% [markdown]
# Importa los paquetes y módulos que necesites a lo largo del notebook.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## #1

# %% [markdown]
# ### #1.1

# %% [markdown]
# Carga el dataset de casas de California que está en la ruta "./data/california_cities.csv". Muestra parte de su contenido y su descripción. Deshazte de las filas con nulos.

# %%
df_california_cities = pd.read_csv("./data/california_cities.csv")
df_california_cities
# Out:
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 0             0     Adelanto  34.576111 -117.432778        875.0
# 1             1  AgouraHills  34.153333 -118.761667        281.0
# 2             2      Alameda  37.756111 -122.274444          NaN
# 3             3       Albany  37.886944 -122.297778          NaN
# 4             4     Alhambra  34.081944 -118.135000        150.0
# ..          ...          ...        ...         ...          ...
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0          2871.0             31765            56.027           56.009
# ...

# %% [markdown]
# ### #1.2
#
# Recrea la siguiente figura, para ello construye en apartados separados cada gráfico y luego haz un apartado en el que se junten los cuatro. Las figuras son:
# 1. Las ciudades más pobladas, con los numeros de las poblaciones (tendrás que usar texto y recordar que para centrarlos se necesita poner el argumento `ha` a "center").
# 2. Histograma del área total ocupada por las ciudades.
# 3. El scatter de área de agua de un ciudad con su poblacion.
# 4. El boxplot de la altura de las ciudades.

# %% [markdown]
# ![figura_ejempo.png](attachment:figura_ejempo.png)

# %%
#2. Histograma del área total ocupada por las ciudades.
plt.hist(df_california_cities['area_total_km2'], bins=45, color='skyblue', alpha=0.8)
plt.set_ylabel(f"Número de ciudades")
plt.set_xlabel(f"Superfice ($km^2$)")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 3
#       1 #2. Histograma del área total ocupada por las ciudades.
#       2 plt.hist(df_california_cities['area_total_km2'], bins=45, color='skyblue', alpha=0.8)
# ----> 3 plt.set_ylabel(f"Número de ciudades")
#       4 plt.set_xlabel(f"Superfice ($km^2$)")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_ylabel'

# %%
#3. El scatter de área de agua de un ciudad con su poblacion.
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19d02ed30a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19d02ed20e0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x19d02ed1570>],
#  'medians': [<matplotlib.lines.Line2D at 0x19d02ed2a70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19d02ed0100>],
#  'means': []}

# %%
#4. El boxplot de la altura de las ciudades.
plt.boxplot(df_california_cities["elevation_m"].dropna(), boxprops= {"facecolor": "red", "color": "blue"}, patch_artist= True, whis = 3,vert=False)
#plt.set_title('Diagrama de las cajas de la Altitud de las ciudades de California')

# %%
#Dibuja los 4 gráficos
fig, axs = plt.subplots(2, 2, figsize=(20, 16))
#plt.boxplot()

# Boxplot
#axs[0, 1].boxplot(titanic_data["fare"], boxprops= {"facecolor": "blue", "color": "red"}, 
#            patch_artist= True, whis = 3)
#axs[0, 1].set_title('Boxplot de Tarifas')
#axs[0, 1].axis("off")
top = 5
colors=["green","gray","orange","brown","pink"]

frecuencias = df_california_cities.population_total.sort_values(ascending = False).head(top) / 1000
lista=frecuencias.index.to_list()
#print(lista)
categorias = df_california_cities["city"].filter(items=lista,axis=0)
#print("filtro:",categorias)
#categorias = df_california_cities[filtro]["city"]
#print(categorias)
axs[0,0].bar(categorias, frecuencias,color=colors)
#axs[0,0].bar(categorias, frecuencias,hue="colors")
axs[0, 0].set_title(f"Ciudades más pobladas de California")
#for index,data in enumerate(frecuencias):
 #   axs[0,0].text(x=index , y =data+1 , s=f"{data}" , fontdict=dict(fontsize=15))
for i, v in enumerate(frecuencias):
    axs[0,0].text(i-.25, 
            frecuencias.iloc[i]+10, 
            frecuencias.iloc[i], 
            fontsize=14)
# Histograma 0,1
axs[0, 1].hist(df_california_cities['area_total_km2'], bins=45, color='skyblue', alpha=0.8)
axs[0, 1].set_ylabel(f"Número de ciudades")
axs[0, 1].set_xlabel(f"Superfice ($km^2$)")



# Dispersion
props_flecha={
    "arrowstyle":"<->",
}
#axs[1, 0].annotate("Outliers", xy = (df_california_cities['area_total_km2'].max(),\
 #                                   df_california_cities['area_total_km2'].max()), xytext=(df_california_cities['area_total_km2'],0.5))
  #                                      arrowprops=props_flecha)

axs[1, 0].scatter(df_california_cities['area_total_km2'],df_california_cities['population_total']/1000, alpha=0.25,color="g")
#axs[1, 0].scatter.set_text(3000,700,"Outliers")
axs[1, 0].set_title('Población por kilómetro cuadrado de agua')
axs[1, 0].set_ylabel('Población (miles habitantes)')
axs[1, 0].set_xlabel('Area de agua en la ciudad (km2)')
axs[1, 0].annotate('Outliers',xy=(3500,80))

# Gráfico de Errores
#axs[1,1].boxplot
axs[1, 1].boxplot(df_california_cities["elevation_m"].dropna(), boxprops= {"facecolor": "red", "color": "black"}, patch_artist= True, whis = 3,vert=False)
axs[1, 1].set_title('Diagrama de las cajas de la Altitud de las ciudades de California')
#axs[1, 1].axis("off")

#axs[1, 1].errorbar(mean_fare_by_age.index, mean_fare_by_age, yerr=std_fare_by_age, fmt='o', ecolor='red', alpha=0.7)
#axs[1,1].set_title('Edad vs Tarifa Promedio en el Titanic')
#axs[1,1].set_xlabel('Edad')
#axs[1,1].set_ylabel('Tarifa Promedio (£)')

#plt.suptitle("Ejercicio EXTRA")

plt.tight_layout()
plt.show()
fig.savefig("./data/20231212.png")

# %%
from pylab import *
from numpy import outer
rc('text', usetex=False)
a=outer(arange(0,1,0.01),ones(10))
figure(figsize=(10,5))
subplots_adjust(top=0.8,bottom=0.05,left=0.01,right=0.99)
maps=[m for m in cm.datad if not m.endswith("_r")]
maps.sort()
l=len(maps)+1
for i, m in enumerate(maps):
    subplot(1,l,i+1)
    axis("off")
    imshow(a,aspect='auto',cmap=get_cmap(m),origin="lower")
    title(m,rotation=90,fontsize=10)

# %% [markdown]
# ### #1.3
#
# Graba la figura en un archivo y sube el archivo a tu repo personal también.
