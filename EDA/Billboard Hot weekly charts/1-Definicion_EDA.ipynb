# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = "Artistas o grupos musicales con más exitos"

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown
tema = "Exitos musicales desde 1966"

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %%
# Escribe tu hipótesis principal en Markdown
hipotesis_1 = "Qué grupo o artista es el que más éxitos ha tenido desde 1966"

# %%
# Escribe más hipótesis si las hubiera en Markdown
hipotesis_2 = "Que grupo o artista llevan más años en las listas más tiempo y de que generos"
hipotesis_3 = "Que grupo o artista llevan más exitos en los ultimos 10 años y de que generos"
hipotesis_4 = "Qué grupo o artista han sido 1 hit wonder y de que generos"
hipotesis_5 = "Que generos corresponden a cada grupo o artista anterior"

# ...

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
# guarda en variables los datasets y su fuente
df_Hot_100_Audio_Features = pd.read_csv("./data/Hot_100_Audio_Features.csv").set_index('index')
df_Hot_Stuff = pd.read_csv("./data/Hot_Stuff.csv").set_index('index')

fuente_1 = ""
# df_2 = pd.DataFrame()
# fuente_2 = ""
# df_3 = pd.DataFrame()
# fuente_3 = ""
# df_4 = pd.DataFrame()
# fuente_4 = ""
# df_5 = pd.DataFrame()
# fuente_5 = ""
# ...

# %%
df_Hot_Stuff.sort_values("WeekID")
# Out:
#                                                       url    WeekID  \
# index
# 68947   http://www.billboard.com/charts/hot-100/1966-0...  1/1/1966
# 248727  http://www.billboard.com/charts/hot-100/1966-0...  1/1/1966
# 204841  http://www.billboard.com/charts/hot-100/1966-0...  1/1/1966
# 63208   http://www.billboard.com/charts/hot-100/1966-0...  1/1/1966
# 109649  http://www.billboard.com/charts/hot-100/1966-0...  1/1/1966
# ...                                                   ...       ...
# 275323  http://www.billboard.com/charts/hot-100/2017-0...  9/9/2017
# 155192  http://www.billboard.com/charts/hot-100/2017-0...  9/9/2017
# 312908  http://www.billboard.com/charts/hot-100/2017-0...  9/9/2017
# 132188  http://www.billboard.com/charts/hot-100/2017-0...  9/9/2017
# 303302  http://www.billboard.com/charts/hot-100/2017-0...  9/9/2017
#
#         Week Position                               Song  \
# index
# 68947               1               The Sound Of Silence
# 248727             87  Love (Makes Me Do Foolish Things)
# 204841             67                    Zorba The Greek
# 63208              64              Please Don't Fight It
# 109649             74                            My Love
# ...               ...                                ...
# 275323             13              Body Like A Back Road
# 155192             12                       Bank Account
# 312908             39                        No Promises
# 132188             38                           What Ifs
# 303302             87                           Reminder
#
#                                  Performer  \
# index
# 68947                    Simon & Garfunkel
# 248727              Martha & The Vandellas
# 204841     Herb Alpert & The Tijuana Brass
# 63208                   Dino, Desi & Billy
# 109649                        Petula Clark
# ...                                    ...
# 275323                            Sam Hunt
# 155192                           21 Savage
# 312908   Cheat Codes Featuring Demi Lovato
# 132188  Kane Brown Featuring Lauren Alaina
# 303302                          The Weeknd
#
#                                                    SongID  Instance  \
# index
# 68947               The Sound Of SilenceSimon & Garfunkel         1
# 248727  Love (Makes Me Do Foolish Things)Martha & The ...         1
# 204841     Zorba The GreekHerb Alpert & The Tijuana Brass         1
# 63208             Please Don't Fight ItDino, Desi & Billy         1
# 109649                                My LovePetula Clark         1
# ...                                                   ...       ...
# 275323                      Body Like A Back RoadSam Hunt         1
# 155192                              Bank Account21 Savage         1
# 312908       No PromisesCheat Codes Featuring Demi Lovato         1
# 132188         What IfsKane Brown Featuring Lauren Alaina         1
# 303302                                 ReminderThe Weeknd         3
#
#         Previous Week Position  Peak Position  Weeks on Chart
# index
# 68947                      5.0              1               7
# 248727                    91.0             87               4
# 204841                    82.0             67               2
# 63208                     67.0             64               4
# 109649                    90.0             74               2
# ...                        ...            ...             ...
# 275323                    10.0              6              30
# 155192                    12.0             12               7
# 312908                    43.0             39              15
# 132188                    44.0             38              11
# 303302                    76.0             65              16
#
# [327895 rows x 10 columns]

# %%
df_result = pd.merge(df_Hot_100_Audio_Features, df_Hot_Stuff, how="inner", on=["Song", "SongID"])

# %%
df_result
# Out:
#                                                    SongID         Performer_x  \
# 0          -twistin'-White Silver SandsBill Black's Combo  Bill Black's Combo
# 1          -twistin'-White Silver SandsBill Black's Combo  Bill Black's Combo
# 2       ¿Dònde Està Santa Claus? (Where Is Santa Claus...          Augie Rios
# 3       ¿Dònde Està Santa Claus? (Where Is Santa Claus...          Augie Rios
# 4       ¿Dònde Està Santa Claus? (Where Is Santa Claus...          Augie Rios
# ...                                                   ...                 ...
# 330223                                       Zunga ZengK7                  K7
# 330224                                       Zunga ZengK7                  K7
# 330225                                       Zunga ZengK7                  K7
# 330226                                       Zunga ZengK7                  K7
# 330227                                       Zunga ZengK7                  K7
#
#                                                     Song  spotify_genre  \
# 0                           -twistin'-White Silver Sands             []
# 1                           -twistin'-White Silver Sands             []
# 2       ¿Dònde Està Santa Claus? (Where Is Santa Claus?)    ['novelty']
# 3       ¿Dònde Està Santa Claus? (Where Is Santa Claus?)    ['novelty']
# 4       ¿Dònde Està Santa Claus? (Where Is Santa Claus?)    ['novelty']
# ...                                                  ...            ...
# 330223                                        Zunga Zeng  ['freestyle']
# 330224                                        Zunga Zeng  ['freestyle']
# 330225                                        Zunga Zeng  ['freestyle']
# 330226                                        Zunga Zeng  ['freestyle']
# 330227                                        Zunga Zeng  ['freestyle']
#
#               spotify_track_id  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 330223  0XevPPcCBPovknaBw3lFvh
# 330224  0XevPPcCBPovknaBw3lFvh
# 330225  0XevPPcCBPovknaBw3lFvh
# 330226  0XevPPcCBPovknaBw3lFvh
# 330227  0XevPPcCBPovknaBw3lFvh
#
#                                 spotify_track_preview_url  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 330223  https://p.scdn.co/mp3-preview/8d5174aeb7d6b740...
# 330224  https://p.scdn.co/mp3-preview/8d5174aeb7d6b740...
# 330225  https://p.scdn.co/mp3-preview/8d5174aeb7d6b740...
# 330226  https://p.scdn.co/mp3-preview/8d5174aeb7d6b740...
# 330227  https://p.scdn.co/mp3-preview/8d5174aeb7d6b740...
#
#         spotify_track_duration_ms spotify_track_explicit spotify_track_album  \
# 0                             NaN                    NaN                 NaN
# 1                             NaN                    NaN                 NaN
# 2                             NaN                    NaN                 NaN
# 3                             NaN                    NaN                 NaN
# 4                             NaN                    NaN                 NaN
# ...                           ...                    ...                 ...
# 330223                   273000.0                  False  Swing Batta Swing!
# 330224                   273000.0                  False  Swing Batta Swing!
# 330225                   273000.0                  False  Swing Batta Swing!
# 330226                   273000.0                  False  Swing Batta Swing!
# 330227                   273000.0                  False  Swing Batta Swing!
#
#         danceability  ...  time_signature  spotify_track_popularity  \
# 0                NaN  ...             NaN                       NaN
# 1                NaN  ...             NaN                       NaN
# 2                NaN  ...             NaN                       NaN
# 3                NaN  ...             NaN                       NaN
# 4                NaN  ...             NaN                       NaN
# ...              ...  ...             ...                       ...
# 330223         0.846  ...             4.0                      28.0
# 330224         0.846  ...             4.0                      28.0
# 330225         0.846  ...             4.0                      28.0
# 330226         0.846  ...             4.0                      28.0
# 330227         0.846  ...             4.0                      28.0
#
#                                                       url      WeekID  \
# 0       http://www.billboard.com/charts/hot-100/1962-0...    5/5/1962
# 1       http://www.billboard.com/charts/hot-100/1962-0...   5/19/1962
# 2       http://www.billboard.com/charts/hot-100/1958-1...  12/13/1958
# 3       http://www.billboard.com/charts/hot-100/1958-1...  12/20/1958
# 4       http://www.billboard.com/charts/hot-100/1958-1...  12/27/1958
# ...                                                   ...         ...
# 330223  http://www.billboard.com/charts/hot-100/1994-0...    4/9/1994
# 330224  http://www.billboard.com/charts/hot-100/1994-0...   4/16/1994
# 330225  http://www.billboard.com/charts/hot-100/1994-0...   4/23/1994
# 330226  http://www.billboard.com/charts/hot-100/1994-0...   4/30/1994
# 330227  http://www.billboard.com/charts/hot-100/1994-0...    5/7/1994
#
#         Week Position         Performer_y  Instance  Previous Week Position  \
# 0                  92  Bill Black's Combo         1                     NaN
# 1                  96  Bill Black's Combo         2                     NaN
# 2                  66          Augie Rios         1                     NaN
# 3                  53          Augie Rios         1                    66.0
# 4                  47          Augie Rios         1                    53.0
# ...               ...                 ...       ...                     ...
# 330223             75                  K7         1                    71.0
# 330224             70                  K7         1                    75.0
# 330225             75                  K7         1                    70.0
# 330226             82                  K7         1                    75.0
# 330227             87                  K7         1                    82.0
#
#         Peak Position  Weeks on Chart
# 0                  92               1
# 1                  96               2
# 2                  66               1
# 3                  53               2
# 4                  47               3
# ...               ...             ...
# 330223             61              11
# 330224             61              12
# 330225             61              13
# 330226             61              14
# 330227             61              15
#
# [330228 rows x 30 columns]

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
df_Hot_100_Audio_Features
# Out:
#                                                   SongID  \
# index
# 0         -twistin'-White Silver SandsBill Black's Combo
# 1      ¿Dònde Està Santa Claus? (Where Is Santa Claus...
# 2                 ......And Roses And RosesAndy Williams
# 3               ...And Then There Were DrumsSandy Nelson
# 4                    ...Baby One More TimeBritney Spears
# ...                                                  ...
# 29498  Zoo YorkLil Tjay Featuring Fivio Foreign & Pop...
# 29499                                         ZoomFuture
# 29500                 ZoomLil' Boosie Featuring Yung Joc
# 29501     Zorba The GreekHerb Alpert & The Tijuana Brass
# 29502                                       Zunga ZengK7
#
#                                           Performer  \
# index
# 0                                Bill Black's Combo
# 1                                        Augie Rios
# 2                                     Andy Williams
# 3                                      Sandy Nelson
# 4                                    Britney Spears
# ...                                             ...
# 29498  Lil Tjay Featuring Fivio Foreign & Pop Smoke
# 29499                                        Future
# 29500                Lil' Boosie Featuring Yung Joc
# 29501               Herb Alpert & The Tijuana Brass
# 29502                                            K7
#
#                                                    Song  \
# index
# 0                          -twistin'-White Silver Sands
# 1      ¿Dònde Està Santa Claus? (Where Is Santa Claus?)
# 2                             ......And Roses And Roses
# 3                          ...And Then There Were Drums
# 4                                 ...Baby One More Time
# ...                                                 ...
# 29498                                          Zoo York
# 29499                                              Zoom
# 29500                                              Zoom
# 29501                                   Zorba The Greek
# 29502                                        Zunga Zeng
#
#                                            spotify_genre  \
# index
# 0                                                     []
# 1                                            ['novelty']
# 2      ['adult standards', 'brill building pop', 'eas...
# 3       ['rock-and-roll', 'space age pop', 'surf music']
# 4                  ['dance pop', 'pop', 'post-teen pop']
# ...                                                  ...
# 29498                                                NaN
# 29499  ['atl hip hop', 'hip hop', 'pop rap', 'rap', '...
# 29500          ['baton rouge rap', 'deep southern trap']
# 29501    ['adult standards', 'easy listening', 'lounge']
# 29502                                      ['freestyle']
#
#              spotify_track_id  \
# index
# 0                         NaN
# 1                         NaN
# 2      3tvqPPpXyIgKrm4PR9HCf0
# 3      1fHHq3qHU8wpRKHzhojZ4a
# 4      3MjUtNVVq3C8Fn0MP3zhXa
# ...                       ...
# 29498                     NaN
# 29499  2IG6Te7JyvrtqhFeOF7le4
# 29500                     NaN
# 29501  3WLEVNohakzZmMpN5W7mHK
# 29502  0XevPPcCBPovknaBw3lFvh
#
#                                spotify_track_preview_url  \
# index
# 0                                                    NaN
# 1                                                    NaN
# 2      https://p.scdn.co/mp3-preview/cef4883cfd1e0e53...
# 3                                                    NaN
# 4      https://p.scdn.co/mp3-preview/da2134a161f1cb34...
# ...                                                  ...
# 29498                                                NaN
# 29499  https://p.scdn.co/mp3-preview/cb8fde6edc08e70a...
# 29500                                                NaN
# 29501  https://p.scdn.co/mp3-preview/1841a4034ba42fc0...
# 29502  https://p.scdn.co/mp3-preview/8d5174aeb7d6b740...
#
#        spotify_track_duration_ms spotify_track_explicit  \
# index
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                       166106.0                  False
# 3                       172066.0                  False
# 4                       211066.0                  False
# ...                          ...                    ...
# 29498                        NaN                    NaN
# 29499                   278429.0                   True
# 29500                        NaN                    NaN
# 29501                   264853.0                  False
# 29502                   273000.0                  False
#
#                                   spotify_track_album  danceability  ...  \
# index                                                                ...
# 0                                                 NaN           NaN  ...
# 1                                                 NaN           NaN  ...
# 2                         The Essential Andy Williams         0.154  ...
# 3                               Compelling Percussion         0.588  ...
# 4      ...Baby One More Time (Digital Deluxe Version)         0.759  ...
# ...                                               ...           ...  ...
# 29498                                             NaN           NaN  ...
# 29499                                          FUTURE         0.852  ...
# 29500                                             NaN           NaN  ...
# 29501                              !!!Going Places!!!         0.531  ...
# 29502                              Swing Batta Swing!         0.846  ...
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# index
# 0           NaN   NaN          NaN           NaN               NaN       NaN
# 1           NaN   NaN          NaN           NaN               NaN       NaN
# 2       -14.063   1.0       0.0315       0.91100          0.000267    0.1120
# 3       -17.278   0.0       0.0361       0.00256          0.745000    0.1450
# 4        -5.745   0.0       0.0307       0.20200          0.000131    0.4430
# ...         ...   ...          ...           ...               ...       ...
# 29498       NaN   NaN          NaN           NaN               NaN       NaN
# 29499    -7.673   1.0       0.4260       0.01450          0.000000    0.2630
# 29500       NaN   NaN          NaN           NaN               NaN       NaN
# 29501   -12.702   1.0       0.3230       0.15400          0.279000    0.0584
# 29502    -9.642   1.0       0.1400       0.04780          0.000363    0.0392
#
#        valence    tempo  time_signature  spotify_track_popularity
# index
# 0          NaN      NaN             NaN                       NaN
# 1          NaN      NaN             NaN                       NaN
# 2        0.150   83.969             4.0                      38.0
# 3        0.801  121.962             4.0                      11.0
# 4        0.907   92.960             4.0                      77.0
# ...        ...      ...             ...                       ...
# 29498      NaN      NaN             NaN                       NaN
# 29499    0.627  150.945             4.0                      51.0
# 29500      NaN      NaN             NaN                       NaN
# 29501    0.192   82.107             4.0                      35.0
# 29502    0.619  103.743             4.0                      28.0
#
# [29503 rows x 22 columns]

# %%
# Siguiente dataset...
# df_2.head()

# %%
df["chart_date_as_date"] = pd.to_datetime(df["chart_date"])
df["chart_debut_as_date"] = pd.to_datetime(df["chart_debut"])
df["time_on_chart_as_date"] = df["chart_date_as_date"] - df["chart_debut_as_date"]

# %%
df.chart_url = '"' + df.chart_url + '"'

# %%
df.chart_url
# Out:
# 0         "https://www.billboard.com/charts/hot-100/1990...
# 1         "https://www.billboard.com/charts/hot-100/1990...
# 2         "https://www.billboard.com/charts/hot-100/1990...
# 3         "https://www.billboard.com/charts/hot-100/1990...
# 4         "https://www.billboard.com/charts/hot-100/1990...
#                                 ...
# 338390    "https://www.billboard.com/charts/hot-100/2001...
# 338391    "https://www.billboard.com/charts/hot-100/1958...
# 338392    "https://www.billboard.com/charts/hot-100/1958...
# 338393    "https://www.billboard.com/charts/hot-100/1958...
# 338394    "https://www.billboard.com/charts/hot-100/1959...
# Name: chart_url, Length: 338395, dtype: object
